# %% [markdown]
# # NY TAXI DATA SCIENCE EXCERCISE

# %% [markdown]
# ### Basic Questions:
#
# 1. What are the distributions of the number of passengers per trip, payment type, fare amount, tip amount, and total amount?
#
# 2. What are top 5 busiest hours of the day, and the top 10 busiest locations of the city?
#
# 3. What is the hourly taxi activity for each day of the week?
#
# 4. Which trip has the most consistent fares?
#
#
# ### Open Questions:
#
#
# 1. Can you predict the fare and tip amount based on the pickup / drop off location, time, and day of the week?
#
# 2. Can you predict the pickup / drop off geographical distribution for each hour of a weekday?
#
# 3. If you were a taxi owner, how would you maximize your earnings in a day?
#
# 4. If you run a taxi company, how would you maximize your earnings?

# %%
import pandas as pd
import numpy as np
import matplotlib  
import matplotlib.pyplot as plt 

df = pd.read_csv('yellow_tripdata_2016-01.csv')
df
test=df.iloc[0:10,13]
import plotly.plotly as py
from plotly.offline import init_notebook_mode, iplot, plot
import plotly.graph_objs as gotest
# Out:
# 0    0.5
# 1    0.5
# 2    0.5
# 3    0.0
# 4    0.0
# 5    0.5
# 6    0.5
# 7    0.5
# 8    0.5
# 9    0.5
# Name: extra, dtype: float64

# %%
import plotly
plotly.tools.set_credentials_file(username='eosg', api_key='AmlsmkQM0FkVbEPtlQSf')

# %%
import plotly.plotly as py
from plotly.offline import init_notebook_mode, iplot, plot

import plotly.graph_objs as go

#x = np.random.randn(500)
#data = [go.Histogram(x=x)]

#py.iplot(data, filename='basic histogram')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-5e1082a609c2> in <module>()
#       1 import plotly.plotly as py
#       2 from plotly.offline import init_notebook_mode, iplot, plot
# ----> 3 py.tools.set_credentials_file(username='eosg', api_key='AmlsmkQM0FkVbEPtlQSf')
#       4
#       5 #import plotly.graph_objs as go
#
# AttributeError: module 'plotly.plotly' has no attribute 'tools'

# %%
import plotly.plotly as py
from plotly.graph_objs import *

#isa
import plotly.plotly as py
from plotly.offline import init_notebook_mode, iplot, plot
import plotly.graph_objs as go
from plotly import tools
init_notebook_mode()
trace = []
trace.append(go.Scatter(
   y = st))

fig = go.Figure(data = trace, layout = go.Layout(title = 'All the seizures'))
iplot(fig)

# %%
matplotlib.style.use('ggplot')

plt.figure();

df.iloc[:,13].plot(kind='hist');




#P=df.plot(kind='hist', x='pickup_longitude', y='pickup_latitude',color='white',xlim=(-74.06,-73.77),ylim=(40.61, 40.91),s=.02,alpha=.6)

# %%
# Map the pick up and drop off locations

import matplotlib  
import matplotlib.pyplot as plt 

pd.options.display.mpl_style = 'default' #Better Styling 

new_style = {'grid': False} #Remove grid  
matplotlib.rc('axes', **new_style)  
from matplotlib import rcParams  
rcParams['figure.figsize'] = (17.5, 17) #Size of figure  
rcParams['figure.dpi'] = 250

P=df.plot(kind='scatter', x='pickup_longitude', y='pickup_latitude',color='white',xlim=(-74.06,-73.77),ylim=(40.61, 40.91),s=.02,alpha=.6)
P.set_axis_bgcolor('black') #Background Color
# Out:
# C:\Users\elmaog\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\elmaog\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:14: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.

# %%
#classfiy into manhattan, JFK airport, laGuardia

#Q's what percentage are those airport trips
# map the fare disputes
